# %% [markdown]
# ## Assignment 3: Web Scraping
#
# For this assignment, you are required to scrape data from e-commerce or other websites such as [Lelong](http://www.lelong.com.my), [Lazada](http://www.lazada.com.my/), [Mudah](http://www.mudah.my/), [iProperty](https://www.iproperty.com.my/), [Booking](http://www.booking.com), [Expedia](https://www.expedia.com.my/) etc.
#
# You are required to fork this Jupyter Notebook from my Github [here](https://github.com/kuanhoong/EDS-Assignment3 ) and then scrape the latest 1000 items from one of the website mentioned above. The scraped data should include:
#
# * Product Name/Product Title
# * Amount/Price
# * Brand
# * Comments/Reviews
# * Number of views
#
# In addition, you are required to export the scraped data to dataframe format and also save a copy in csv format. Upon successful extracting data to dataframe, you are required to do a data analysis on the data.
#
# Your analysis should provide answers to the following questions:
# * What do you think is interesting about this data? Tell a story about some interesting thing you have discovered by looking at the data.
# * Visualize your data with matplotlib or with folium library package.
#
# For example, you might consider whether there is a difference in pricings at different times doing the day or city, or whether other factors that influnced the pricings etc. Another thing you might consider is whether there is a relationship between the pricing and number of reviews or comments.
#
# Show your analysis workflow in your Jupyter notebook.
#
# The final submission should be pushed back to your respective Github account.

# %% [markdown]
# ### Folium
#
# [Folium](https://github.com/python-visualization/folium) makes it easy to visualize data that's been manipulated in Python on an interactive Leaflet map. It enables both the binding of data to a map for choropleth visualizations as well as passing Vincent/Vega visualizations as markers on the map.

# %%
import pandas as pd
import re
import numpy as np
import folium
import matplotlib.pyplot as plt
# %matplotlib inline
from bs4 import BeautifulSoup
import requests

# %%
mapit = None
latlon = [ (3.144473, 101.708722), (3.144473, 101.708722),(3.135732, 101.686989)]
for coord in latlon:
    mapit = folium.Map( location=[ coord[0], coord[1] ] )
    folium.Marker([3.144473, 101.708722], icon=folium.Icon(color='blue',icon='star'), popup='Federal Hotel').add_to(mapit)
    folium.Marker([3.156374, 101.714579], icon=folium.Icon(color='green',icon='info-sign') , popup='Mandarin Oriental').add_to(mapit)
    folium.Marker([3.135732, 101.686989], icon=folium.Icon(color='red',icon='star') , popup='Le Meridien').add_to(mapit)
mapit
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# scrape from lelong

# find the pattern for the first page
url = 'https://www.lelong.com.my/catalog/all/list?TheKeyword=macbook+pro&D='

# write a loop to scrape from page 1 to the last page

product_name=[]
for page in range(1,19):
    url_page = url+str(page)
    scrape = requests.get(url_page)
    soup = BeautifulSoup(scrape.content, 'lxml')
    link = soup.find_all('div',{'class':'item','class':'summary'})
    length = len(link)
    for i in range(0,length):
        name = link[i].a.get('title')
        product_name.append(name)

# %%
# write to csv
# convert the list to a pandas dataframe

df = pd.DataFrame({'name':product_name})
df
df.to_csv('output.csv', index=False)

# %%
#Jason Phoon Answer for lelong.com.my
#The scraped data should include:
#Product Name/Product Title
#Amount/Price
#Brand
#Comments/Reviews
#Number of views

url = 'https://www.lelong.com.my/catalog/all/list?TheKeyword=macbook+pro&D='

names = []
prices = []
views = []

#rewrite...
for page in range(1,19):
    url_page = url+str(page)
    scrape = requests.get(url_page)
    soup = BeautifulSoup(scrape.content, 'lxml')
    for item in soup.find_all('div',{'class':'item'}):
        names.append(item.find('div',{'class':'summary'}).a.get('title'))
        prices.append(item.find('div',{'class':'col total'}).span.b.string)
        views.append(item.find('div',{'class':'list-sv-icon'}).find('span',{'class':'hit'}).string)
    
df = pd.DataFrame({'name':names, 'price': prices, 'view': views})
df.price = df.price.str.replace('RM','')
df.view = df.price.str.extract(r'(\d+)')

df.to_csv('output.csv', index=False)

df.tail()
# Out:
# C:\Users\pho01\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#                                                    name    price view
# 1028         New Battery APPLE Macbook PRO A1161 Bateri   480.00  480
# 1029         New Battery APPLE Macbook Pro A1278 Bateri   480.00  480
# 1030        New Adapter APPLE Macbook PRO A1502 Charger   300.00  300
# 1031  Thunderbolt Mini Displayport DP to VGA Adapter...    30.90   30
# 1032  Apple MacBook Pro 13 13.3 A1278 Transparent Cr...    29.99   29

# %%
#Jason Phoon: 
#Date Completed: 23 July 2017
#User Stories: Compare Bangsar, KLCC, Subang Jaya, Petaling Jaya, Kota Kemuning and Denai Alam Property Prices over posted date time

def scrapeWeb(url, location):
    #process data
    property_titles = []
    property_furnish = []
    property_type = []
    property_posted_date = []
    property_price = []
    
    for page in range(1,50):
        url_page = url+str(page)
        scrape = requests.get(url_page)
        soup = BeautifulSoup(scrape.content, 'lxml')

        for media in soup.find_all('div',{'class':'media'}):
            title = media.find('h4',{'class','media-heading'}).a.string
            property_titles.append(title)

            facilities = media.find('div',{'class','media-body'}).find('ul',{'class','list-inline'}).find_all('li')

            if(len(facilities) > 2):
                furnish = (facilities[0].string.replace('\xa0|',''))
                ptype = (facilities[1].string.replace('\xa0|',''))
                posted_date = (facilities[2].string)
            else:
                furnish = (facilities[0].string.replace('\xa0|',''))
                ptype = ''
                posted_date = (facilities[1].string.replace('\xa0|',''))

            property_furnish.append(furnish)
            property_type.append(ptype)
            property_posted_date.append(posted_date)

            price = media.find('p',{'style':'margin:1%;font-weight:bold;font-size:25px;font-size:25px !important;line-height:15px;'})
            match = re.findall(r'>(.+?)<', str(price))
            if(len(match) > 1):
                total_price = match[0]
            else:
                total_price = 0

            property_price.append(total_price)

    return pd.DataFrame({'title':property_titles,
                         'location': location,
                         'type': property_type,
                         'posted_date': property_posted_date,
                         'furnish': property_furnish,
                         'original_price': property_price,
                         'total_price': '0',})

property_bangsar_df = scrapeWeb('http://www.propwall.my/bangsar/classifieds?tab=Most%20Relevance&keywords=Bangsar%2C%20Kuala%20Lumpur&filter_id=18&filter_type=Location&listing=For%20Sale&view=list&map=off&blurb=0&page='
,'Bangsar')
property_klcc_df = scrapeWeb('http://www.propwall.my/klcc/classifieds?tab=Most%20Relevance&keywords=KLCC%2C%20KL%20City%20Centre&filter_id=16&filter_type=Location&listing=For%20Sale&view=list&map=on&blurb=0&page='
,'KLCC')
property_subangjaya_df = scrapeWeb('http://www.propwall.my/subang_jaya/classifieds?tab=Most%20Relevance&keywords=Subang%20Jaya%2C%20Selangor&filter_id=22&filter_type=Location&listing=For%20Sale&view=list&map=on&blurb=0&page='
,'Subang Jaya')
property_petalingjaya_df = scrapeWeb('http://www.propwall.my/petaling_jaya/classifieds?tab=Most%20Relevance&keywords=Petaling%20Jaya%2C%20Selangor&filter_id=21&filter_type=Location&listing=For%20Sale&view=list&map=on&blurb=0&page='
,'Petaling Jaya')
property_kota_kemuning_df = scrapeWeb('http://www.propwall.my/kota_kemuning/classifieds?tab=Most%20Relevance&keywords=Kota%20Kemuning%2C%20Shah%20Alam&filter_id=186&filter_type=Location&listing=For%20Sale&view=list&map=on&blurb=0&page='
,'Kota Kemuning')
property_denai_alam_df = scrapeWeb('http://www.propwall.my/shah_alam/classifieds?tab=Most%20Relevance&keywords=Denai%20Alam%2C%20Shah%20Alam&filter_id=1509&filter_type=Property&listing=For%20Sale&view=list&map=on&blurb=0&page='
,'Denai Alam')

# %%
#property data frame sanitization before analysis
frames = [property_bangsar_df, property_klcc_df, property_subangjaya_df, property_petalingjaya_df, property_kota_kemuning_df, property_denai_alam_df]
property_df = pd.concat(frames)
property_df.reset_index()

#data sanitization
property_df.posted_date = pd.to_datetime(property_df.posted_date.str.replace(' *',''),errors='coerce')
property_df.total_price = property_df.original_price
property_df.total_price = property_df.total_price.str.replace('RM','')
property_df.total_price = property_df.total_price.str.replace(',','')
property_df.total_price = property_df.total_price.str.replace(' ','')
property_df.total_price = property_df.total_price.str.strip()
property_df.total_price = pd.to_numeric(property_df.total_price)
property_df.total_price = property_df.total_price/1000

property_df = property_df[(property_df.total_price > 0) 
                          & (property_df.posted_date <= pd.to_datetime('today'))
                          & (property_df.type != 'Shop')
                          & (property_df.type != 'Land')
                          & (property_df.type != 'Office')
                          & (property_df.type != 'Factory')]

print(len(property_df))
property_df.head()
# Out:
# 1803
#            furnish location original_price posted_date  \
# 0   Semi-Furnished  Bangsar   RM 4,320,000  2017-07-21
# 1   Semi-Furnished  Bangsar   RM 7,900,000  2017-07-21
# 2   Semi-Furnished  Bangsar   RM 3,886,800  2017-07-21
# 3   Semi-Furnished  Bangsar   RM 7,800,000  2017-07-21
# 4  Fully Furnished  Bangsar   RM 2,600,000  2017-07-20
#
#                         title  total_price         type
# 0       One Menerung, Bangsar       4320.0  Condominium
# 1       One Menerung, Bangsar       7900.0  Condominium
# 2       One Menerung, Bangsar       3886.8  Condominium
# 3       One Menerung, Bangsar       7800.0  Condominium
# 4  Zehn Bukit Pantai, Bangsar       2600.0  Condominium

# %%
#Find top 3 highest price
top3 = property_df.sort_values('total_price', ascending=False)
top3.head(3)
# Out:
#             furnish       location     original_price posted_date  \
# 482  Semi-Furnished           KLCC  RM 10,536,000,000  2017-05-29
# 386     Condominium  Petaling Jaya   RM 1,000,000,000  2017-06-16
# 842     Unfurnished           KLCC      RM 50,000,000  2017-03-05
#
#                       title  total_price         type
# 482       Banyan Tree, KLCC   10536000.0  Condominium
# 386  Maisson, Ara Damansara    1000000.0
# 842    KLCC, KL City Centre      50000.0  Condominium

# %%
print('Average property price in 2017 = RM %d' % (property_df.total_price.mean()*1000))
print('Median property price in 2017  = RM %d' % (property_df.total_price.median()*1000))
# Out:
# Average property price in 2017 = RM 8081398
# Median property price in 2017  = RM 1132000

# %%
#calculate bangsar
bangsar_df  = property_df[(property_df.location == 'Bangsar')]
print('Average Bangsar property price in 2017 = RM %d' % (bangsar_df.total_price.mean()*1000))
bangsar_df = bangsar_df.groupby(bangsar_df.posted_date.dt.month)
bangsar_avg = bangsar_df.mean()

#calculate subang jaya
subang_jaya_df  = property_df[(property_df.location == 'Subang Jaya')]
print('Average Subang Jaya property price in 2017 = RM %d' % (subang_jaya_df.total_price.mean()*1000))
subang_jaya_df = subang_jaya_df.groupby(subang_jaya_df.posted_date.dt.month)
subang_jaya_avg = subang_jaya_df.mean()

#calculate KLCC
klcc_df  = property_df[(property_df.location == 'KLCC')]
print('Average KLCC property price in 2017 = RM %d' % (klcc_df.total_price.mean()*1000))
klcc_df = klcc_df.groupby(klcc_df.posted_date.dt.month)
klcc_avg = klcc_df.mean()

#calculate Petaling Jaya
pj_df = property_df[(property_df.location == 'Petaling Jaya')]
print('Average Petaling Jaya property price in 2017 = RM %d' % (pj_df.total_price.mean()*1000))
pj_df = pj_df.groupby(pj_df.posted_date.dt.month)
pj_df_avg = pj_df.mean()

#calculate Kota Kemuning
kk_df = property_df[(property_df.location == 'Kota Kemuning')]
print('Average Kota Kemuning property price in 2017 = RM %d' % (kk_df.total_price.mean()*1000))
kk_df = kk_df.groupby(kk_df.posted_date.dt.month)
kk_avg = kk_df.mean()

#calculate Denai Alam
da_df = property_df[(property_df.location == 'Denai Alam')]
print('Average Denai Alam property price in 2017 = RM %d' % (da_df.total_price.mean()*1000))
da_df = da_df.groupby(da_df.posted_date.dt.month)
da_avg = da_df.mean()
# Out:
# Average Bangsar property price in 2017 = RM 3373016
# Average Subang Jaya property price in 2017 = RM 997788
# Average KLCC property price in 2017 = RM 18092420
# Average Petaling Jaya property price in 2017 = RM 2796847
# Average Kota Kemuning property price in 2017 = RM 1483689
# Average Denai Alam property price in 2017 = RM 1042186

# %%
#Plot a graph to visualize
#your code here
plt.figure(figsize=(15,5))
plt.plot(bangsar_avg.index, bangsar_avg.total_price, color='g')
plt.ylabel('Mean Property Price in (RM) x 1000')
plt.xlabel('Month')
plt.title('Bangsar')

plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(subang_jaya_avg.index, subang_jaya_avg.total_price, color='r')
plt.ylabel('Mean Property Price in (RM) x 1000')
plt.xlabel('Month')
plt.title('Subang Jaya')

plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(klcc_avg.index, klcc_avg.total_price, color='y')
plt.ylabel('Mean Property Price in (RM) x 1000')
plt.xlabel('Month')
plt.title('KLCC')

plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(pj_df_avg.index, pj_df_avg.total_price, color='b')
plt.ylabel('Mean Property Price in (RM) x 1000')
plt.xlabel('Month')
plt.title('Petaling Jaya')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(kk_avg.index, kk_avg.total_price, color='k')
plt.ylabel('Mean Property Price in (RM) x 1000')
plt.xlabel('Month')
plt.title('Kota Kemuning')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(da_avg.index, da_avg.total_price, color='m')
plt.ylabel('Mean Property Price in (RM) x 1000')
plt.xlabel('Month')
plt.title('Denai Alam')
plt.show()

# %%
#Combine All the 4 graph into 1 place
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(15,17))

axes[0,0].plot(bangsar_avg.index, bangsar_avg.total_price, color='g')
axes[0,0].set_ylabel('Mean Property Price in (RM) x 1000')
axes[0,0].set_xlabel('Month')
axes[0,0].set_title('Bangsar')

axes[0,1].plot(subang_jaya_avg.index, subang_jaya_avg.total_price, color='r')
axes[0,1].set_ylabel('Mean Property Price in (RM) x 1000')
axes[0,1].set_xlabel('Date Posted in Propwall')
axes[0,1].set_title('Subang Jaya')

axes[1,0].plot(klcc_avg.index, klcc_avg.total_price, color='y')
axes[1,0].set_ylabel('Mean Property Price in (RM) x 1000')
axes[1,0].set_xlabel('Date Posted in Propwall')
axes[1,0].set_title('KLCC')

axes[1,1].plot(pj_df_avg.index, pj_df_avg.total_price, color='b')
axes[1,1].set_ylabel('Mean Property Price in (RM) x 1000')
axes[1,1].set_xlabel('Date Posted in Propwall')
axes[1,1].set_title('Petaling Jaya')

axes[2,0].plot(kk_avg.index, kk_avg.total_price, color='k')
axes[2,0].set_ylabel('Mean Property Price in (RM) x 1000')
axes[2,0].set_xlabel('Date Posted in Propwall')
axes[2,0].set_title('Kota Kemuning')

axes[2,1].plot(da_avg.index, da_avg.total_price, color='m')
axes[2,1].set_ylabel('Mean Property Price in (RM) x 1000')
axes[2,1].set_xlabel('Date Posted in Propwall')
axes[2,1].set_title('Denai Alam')

# %%
plt.figure(figsize=(15,6))
plt.plot(bangsar_df.total_price.count(), color = 'g', label='Bangsar')
plt.plot(subang_jaya_df.total_price.count(), color = 'r', label='Subang Jaya')
plt.plot(klcc_df.total_price.count(), color = 'y', label='KLCC')
plt.plot(pj_df.total_price.count(), color = 'b', label='Petaling Jaya')
plt.plot(kk_df.total_price.count(), color = 'k', label='Kota Kemuning')
plt.plot(da_df.total_price.count(), color = 'm', label='Denai Alam')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.title('Total sales in Propwall by Areas')
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.scatter(bangsar_avg.index, bangsar_avg.total_price, c = 'g', label = 'Bangsar')
plt.scatter(subang_jaya_avg.index, subang_jaya_avg.total_price, c = 'r', label = 'Subang Jaya')
plt.scatter(klcc_avg.index, klcc_avg.total_price, c = 'y', label = 'KLCC')
plt.scatter(pj_df_avg.index, pj_df_avg.total_price, c = 'b', label = 'Petaling Jaya')
plt.scatter(kk_avg.index, kk_avg.total_price, c = 'k', label = 'Kota Kemuning')
plt.scatter(da_avg.index, da_avg.total_price, c = 'm', label = 'Denai Alam')
plt.ylim((0,60000))
plt.xlabel('Month')
plt.ylabel('Property Price (RM) x 1000')
plt.legend()
plt.show()

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
location = geolocator.geocode("midvalley")
print(location.address)
print((location.latitude,location.longitude))
# Out:
# Midvalley, Midvale, Salt Lake County, Utah, United States of America
# (40.6124478, -111.8877127)
